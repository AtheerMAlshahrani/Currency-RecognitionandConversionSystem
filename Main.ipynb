# %%
import PySimpleGUI as sg
from tkinter.filedialog import askopenfile
from tkinter import messagebox
import mysql.connector
from tkinter import messagebox
import numpy as np
import tensorflow as tf
from tensorflow import keras
import keras
import cv2
from matplotlib import pyplot as plt
import os
import mysql.connector
import io
from PIL import Image

# %%
def Login_Admin():
    import PySimpleGUI as sg
    from tkinter.filedialog import askopenfile
    from tkinter import messagebox
    import mysql.connector
    mydb = mysql.connector.connect(
        host = "localhost",
        user = "root",
        password = "",
        database = "money_discovery_db")
    sql_Query = "SELECT * FROM admin"
    sg.theme('Light Blue 2')
    layout = [[sg.Text("Money System",text_color='brown',font = "Verdana 22 bold", pad=(175, 0))],
              [sg.Text("Login Admin Page",text_color='brown',font = "Verdana 20 bold", pad=(150, 0))],
              [sg.Text("Admin Name",size=(15,1)),sg.Input(size=(30,1),key='Name')],
              [sg.Text("Admin Password",size=(15,1)),sg.Input(size=(30,1),password_char='*',key='Pass')],
              [sg.Button('Login',size=(10,1))],
              [sg.Text("",text_color='brown',font = "Verdana 22 bold")],
              [sg.Button('back')],
              [sg.Text(size=(50,1), key='-OUTPUT-1')]]
    window = sg.Window('Login Admin Page', layout)
    while True:
        event, values = window.read()
        if event == sg.WINDOW_CLOSED or event == 'Quit':
            break
        if event in (sg.WIN_CLOSED,): 
            break
        if event == 'back':
            main()
            break
        if event == 'Login':
            Name = values['Name']
            Pass = values['Pass']
            mycursor = mydb.cursor()
            mycursor.execute(sql_Query)
            record = mycursor.fetchall()
            for row in record:
                rowUser = row[1]
                rowPass = row[3]
                #messagebox.showinfo("Result", rowEmail)
                #messagebox.showinfo("Result", rowPass)
                if (str(rowUser) == str(Name)) & (str(rowPass) == str(Pass)):
                    messagebox.showinfo("Result", "OK")
                    main_admin()
                    break
    window.close()

# %%
def Main_User():
    import PySimpleGUI as sg
    from tkinter.filedialog import askopenfile
    sg.theme('Light Blue 2')
    layout = [[sg.Text("Money System",text_color='brown',font = "Verdana 22 bold", pad=(175, 0))],
              [sg.Text("Main User Page",text_color='brown',font = "Verdana 20 bold", pad=(175, 0))],
              [sg.Combo(['Use Of Camera', 'Import Photo', 'Exchange Rate', 'Money Type', 'Test Result'], enable_events=True, key='Mcombo',size=(15, 0), pad=(215, 0))],
              [sg.Button('Choose',size=(15, 0), pad=(215, 0))],
              [sg.Button('back')],
              [sg.Text(size=(50,1), key='-OUTPUT-1')]]
    window = sg.Window('Main Admin Page', layout, grab_anywhere=True)
    while True:
        event, values = window.read()
        if event == sg.WINDOW_CLOSED or event == 'Quit':
            break
        if event in (sg.WIN_CLOSED,): 
            break
        if event == 'back':
            main() 
            break
        if event == 'Choose':
            rt = values['Mcombo']
            if rt == "Use Of Camera":
                Umoney_Cap()
                break
            if rt == "Import Photo":
                Umoney_Img()
                break
            if rt == "Exchange Rate":
                View_Exchange_Rate()
                break
            if rt == "Money Type":
                View_Money_Type()
                break
            if rt == "Test Result":
                View_Test_Result()
                break
    window.close()

# %%
def main_admin():
    import PySimpleGUI as sg
    from tkinter.filedialog import askopenfile
    sg.theme('Light Blue 2')
    layout = [[sg.Text("Money System",text_color='brown',font = "Verdana 22 bold", pad=(190, 0))],
              [sg.Text("Main Admin Page",text_color='brown',font = "Verdana 20 bold", pad=(175, 0))],
              [sg.Combo(['Edit My Profile','Edit Money Type','Insert Exchange Rate','Use Of Camera', 'Import Photo', 'Exchange Rate', 'Money Type', 'Test Result'], enable_events=True, key='Mcombo',size=(20, 0), pad=(210, 0))],
              [sg.Button('Choose',size=(15, 0), pad=(225, 0))],
              [sg.Button('back')],
              [sg.Text(size=(50,1), key='-OUTPUT-1')]]
    window = sg.Window('Main Admin Page', layout)
    while True:
        event, values = window.read()
        if event == sg.WINDOW_CLOSED or event == 'Quit':
            break
        if event in (sg.WIN_CLOSED,): 
            break
        if event == 'back':
            main()
            break
        if event == 'Choose':
            rt = values['Mcombo']
            if rt == "Edit My Profile":
                Edit_Profile()
                break
            if rt == "Edit Money Type":
                Edit_Money()
                break
            if rt == "Insert Exchange Rate":
                Insert_An_Exchange_Rate()
                break
            if rt == "Use Of Camera":
                Umoney_Cap()
                break
            if rt == "Import Photo":
                Umoney_Img()
                break
            if rt == "Exchange Rate":
                View_Exchange_Rate()
                break
            if rt == "Money Type":
                View_Money_Type()
                break
            if rt == "Test Result":
                View_Test_Result()
                break
    window.close()

# %%
def View_Test_Result():
    import PySimpleGUI as sg
    import mysql.connector
    sg.theme('Light Blue 2')
    mydb=mysql.connector.connect(
        host="localhost",
        user="root",
        passwd="",
        database="money_discovery_db")
    my_cursor=mydb.cursor()
    my_cursor.execute("SELECT `test_result`, `test_date`, `test_time` FROM `test_al`")
    result=my_cursor.fetchall()
    lists = [list(x) for x in result]
    header_list=["test result","test date","test time"]
    headline_keys=["--test result--","--test date--","--test time--"]
    layout = [[sg.Table(values=lists,
                        key="--Table--",
                        headings=header_list,
                        display_row_numbers=True,
                        auto_size_columns=True,
                        num_rows=20)],
              [sg.Text("",text_color='brown',font = "Verdana 20 bold", pad=(175, 0))],
              [sg.Button('back')],
              [sg.Text(size=(50,1), key='-OUTPUT-1')]]
    window = sg.Window('Test Result Page', layout, grab_anywhere=False)
    while True:
        event, values = window.read()
        if event == sg.WINDOW_CLOSED or event == 'Quit':
            break
        if event in (sg.WIN_CLOSED,): 
            break
        if event == 'back':
            main() 
            break
        if event=="Insert Record":
            value1=window.Element('--test result--').Get()
            value2=window.Element('--test date--').Get()
            value3=window.Element('--test time--').Get()
            window.Element('--Table--').Update(values=[[value1,value2,value3]])
    window.close()

# %%
def View_Money_Type():
    import PySimpleGUI as sg
    import mysql.connector
    sg.theme('Light Blue 2')
    mydb=mysql.connector.connect(
        host="localhost",
        user="root",
        passwd="",
        database="money_discovery_db")
    my_cursor=mydb.cursor()
    my_cursor.execute("SELECT  `banknoteType`, `banknoteNumber`, `banknoteCountry`, `banknote_lable` FROM `banknote`")
    result=my_cursor.fetchall()
    lists = [list(x) for x in result]
    header_list=["Money Type","Money Value","Money Country","Coin Denomination"]
    headline_keys=["--Money Type--","--Money Value--","--Money Country--","--Coin Denomination--"]
    layout = [[sg.Table(values=lists,
                        key="--Table--",
                        headings=header_list,
                        display_row_numbers=True,
                        auto_size_columns=True,
                        num_rows=20)],
              [sg.Text("",text_color='brown',font = "Verdana 20 bold", pad=(175, 0))],
              [sg.Button('back')],
              [sg.Text(size=(50,1), key='-OUTPUT-1')]]
    window = sg.Window('Money Type Page', layout, grab_anywhere=False)
    while True:
        event, values = window.read()
        if event == sg.WINDOW_CLOSED or event == 'Quit':
            break
        if event in (sg.WIN_CLOSED,):
            break
        if event == 'back':
            main()
            break
        if event=="Insert Record":
            value1=window.Element('--Money Type--').Get()
            value2=window.Element('--Money Value--').Get()
            value3=window.Element('--Money Country--').Get()
            value4=window.Element('--Coin Denomination--').Get()
            window.Element('--Table--').Update(values=[[value1,value2,value3,value4]])
    window.close()

# %%
def View_Exchange_Rate():
    import PySimpleGUI as sg
    import mysql.connector
    sg.theme('Light Blue 2')
    mydb=mysql.connector.connect(
        host="localhost",
        user="root",
        passwd="",
        database="money_discovery_db")
    my_cursor=mydb.cursor()
    my_cursor.execute("SELECT `banknoteType`, `lastValue`, `Date` FROM `exchange_rate`")
    result=my_cursor.fetchall()
    lists = [list(x) for x in result]
    header_list=["Money Type","Money Value","Date"]
    headline_keys=["--Money Type--","--Money Value--","--Date--"]
    layout = [[sg.Table(values=lists,
                        key="--Table--",
                        headings=header_list,
                        display_row_numbers=True,
                        auto_size_columns=True,
                        num_rows=20)],
              [sg.Text("",text_color='brown',font = "Verdana 20 bold", pad=(175, 0))],
              [sg.Button('back')],
              [sg.Text(size=(50,1), key='-OUTPUT-1')]]
    window = sg.Window('Exchange Rate Page', layout, grab_anywhere=False)
    while True:
        event, values = window.read()
        if event == sg.WINDOW_CLOSED or event == 'Quit':
            break
        if event in (sg.WIN_CLOSED,): 
            break
        if event == 'back':
            main()
            break
        if event=="Insert Record":
            value1=window.Element('--Money Type--').Get()
            value2=window.Element('--Money Value--').Get()
            value3=window.Element('--Date--').Get()
            window.Element('--Table--').Update(values=[[value1,value2,value3]])
    window.close()

# %%
def Umoney_Img():
    import PySimpleGUI as sg
    from tkinter import messagebox
    import numpy as np
    from tkinter.filedialog import askopenfile
    import tensorflow as tf
    from tensorflow import keras
    import keras
    import cv2
    from matplotlib import pyplot as plt
    import os
    import mysql.connector
    import io
    import os
    from PIL import Image
    model = tf.keras.models.load_model('my_model_money')
    labels = ['10 Sr', '100 Sr', '100 Usd', '1000 Jpy', '1Sr', '200 Sr', '5 Yuan', '50 Eur', '50 Sr', '500 Eur', '500 Sr', '5Sr']
    ########################
    sg.theme('Light Blue 2')
    file_types = [("JPEG (*.jpg)", "*.jpg"),("All files (*.*)", "*.*")]
    layout = [[sg.Image(key="-IMAGE-")],
              [sg.Text("Image File"),
               sg.Input(size=(25, 1), key="-FILE-"),
               sg.FileBrowse(file_types=file_types),
               sg.Button("Load Image")],
              [sg.Text('Result:'), sg.Text(size=(50,1), key='-CSI1-')],
              [sg.Text('Result In USD:'), sg.Text(size=(50,1), key='-CSI2-')],
              [sg.Text('Result IN EURO:'), sg.Text(size=(50,1), key='-CSI3-')],
              [sg.Text('Result In YUAN:'), sg.Text(size=(50,1), key='-CSI4-')],
              [sg.Text('Result In JPY:'), sg.Text(size=(50,1), key='-CSI5-')],
              [sg.Text('Result In SR:'), sg.Text(size=(50,1), key='-CSI6-')],
              [sg.Button('back')],
              [sg.Text(size=(50,1), key='-OUTPUT-1')]]
    window = sg.Window("Money Image Viewer With Test", layout)
    while True:
        event, values = window.read()
        if event == "Exit" or event == sg.WIN_CLOSED:
            break
        if event == 'back':
            main()
            break
        if event == "Load Image":
            filename = values["-FILE-"]
            if os.path.exists(filename):
                image = Image.open(values["-FILE-"])
                image.thumbnail((200, 200))
                bio = io.BytesIO()
                image.save(bio, format="PNG")
                window["-IMAGE-"].update(data=bio.getvalue())
                img_money= cv2.imread(filename)
                imgplot = plt.imshow(img_money)
                img_money = tf.expand_dims(img_money,0)
                img_money=img_money/255
                img_money=tf.image.resize(img_money,size=(224, 224))
                Prob_money=model.predict(img_money)
                ind_money=tf.argmax(Prob_money[0],axis=-1).numpy()
                res_img=str(labels[ind_money])
                mydb = mysql.connector.connect(host = "localhost",
                                               user = "root",
                                               password = "",
                                               database = "money_discovery_db")
                mycursor = mydb.cursor()
                sql1 = "INSERT INTO `test_al`(`test_result`, `test_date`, `test_time`) VALUES ('" + res_img + "',NOW(),NOW())"
                mycursor.execute(sql1)
                mydb.commit()
                #messagebox.showinfo("Result", labels[ind_money] ) 
                sql_Query = "select lastValue * (select banknoteNumber from banknote where banknote_lable like (select test_result from test_al where test_id=(SELECT MAX(test_id) FROM `test_al`))) from exchange_rate where banknoteType like (select banknoteType from banknote where banknote_lable like (select test_result from test_al where test_id=(SELECT MAX(test_id) FROM `test_al`))) ;"
                mycursor.execute(sql_Query)
                recordUSD = mycursor.fetchone()
                sql_Query1 = "select lastValue * (select banknoteNumber from banknote where banknote_lable like (select test_result from test_al where test_id=(SELECT MAX(test_id) FROM `test_al`))) / (SELECT `lastValue` FROM `exchange_rate` WHERE  `banknoteType` like 'EURO' ORDER BY  `currencyID` DESC LIMIT 1)  from exchange_rate where banknoteType like (select banknoteType from banknote where banknote_lable like (select test_result from test_al where test_id=(SELECT MAX(test_id) FROM `test_al`))) ;"
                mycursor.execute(sql_Query1)
                recordEURO = mycursor.fetchone()
                sql_Query2 = "select lastValue * (select banknoteNumber from banknote where banknote_lable like (select test_result from test_al where test_id=(SELECT MAX(test_id) FROM `test_al`))) / (SELECT `lastValue` FROM `exchange_rate` WHERE  `banknoteType` like 'YUAN' ORDER BY  `currencyID` DESC LIMIT 1) from exchange_rate where banknoteType like (select banknoteType from banknote where banknote_lable like (select test_result from test_al where test_id=(SELECT MAX(test_id) FROM `test_al`))) ;"            
                mycursor.execute(sql_Query2)
                recordYUAN = mycursor.fetchone()
                sql_Query3 = "select lastValue * (select banknoteNumber from banknote where banknote_lable like (select test_result from test_al where test_id=(SELECT MAX(test_id) FROM `test_al`))) / (SELECT `lastValue` FROM `exchange_rate` WHERE  `banknoteType` like 'JPY' ORDER BY  `currencyID` DESC LIMIT 1)  from exchange_rate where banknoteType like (select banknoteType from banknote where banknote_lable like (select test_result from test_al where test_id=(SELECT MAX(test_id) FROM `test_al`))) ;"
                mycursor.execute(sql_Query3)
                recordJPY = mycursor.fetchone()
                sql_Query4 = "select lastValue * (select banknoteNumber from banknote where banknote_lable like (select test_result from test_al where test_id=(SELECT MAX(test_id) FROM `test_al`))) / (SELECT `lastValue` FROM `exchange_rate` WHERE  `banknoteType` like 'SR' ORDER BY  `currencyID` DESC LIMIT 1) from exchange_rate where banknoteType like (select banknoteType from banknote where banknote_lable like (select test_result from test_al where test_id=(SELECT MAX(test_id) FROM `test_al`))) ;"
                mycursor.execute(sql_Query4)
                recordSR = mycursor.fetchone()
                mydb.close()
                response1 = "AI system check result: " + res_img
                window['-CSI1-'].update(response1)
                response2 = "AI system check result: " + str(recordUSD)
                window['-CSI2-'].update(response2)
                response3 = "AI system check result: " + str(recordEURO)
                window['-CSI3-'].update(response3)
                response4 = "AI system check result: " + str(recordYUAN)
                window['-CSI4-'].update(response4)
                response5 = "AI system check result: " + str(recordJPY)
                window['-CSI5-'].update(response5)
                response6 = "AI system check result: " + str(recordSR)
                window['-CSI6-'].update(response6)
    window.close()

# %%
def Umoney_Cap():
    import PySimpleGUI as sg
    import keras
    from tkinter import messagebox
    import numpy as np
    import tensorflow as tf
    import numpy as np
    from tkinter.filedialog import askopenfile
    from tensorflow import keras
    import cv2
    from matplotlib import pyplot as plt
    import os
    import mysql.connector
    model = tf.keras.models.load_model('my_model_money')
    labels = ['10 Sr', '100 Sr', '100 Usd', '1000 Jpy', '1Sr', '200 Sr', '5 Yuan', '50 Eur', '50 Sr', '500 Eur', '500 Sr', '5Sr']
    sg.theme('Light Blue 2')
    layout = [[sg.Text("Money System",text_color='brown',font = "Verdana 22 bold", pad=(200, 0))],
              [sg.Text("Use Artificial Intelligence Page",text_color='brown',font = "Verdana 20 bold", pad=(100, 0))],
              [sg.Button('Predect Image Using Camera', pad=(225, 0))],
              [sg.Text('Result:'), sg.Text(size=(50,1), key='-CSI1-')],
              [sg.Text('Result In USD:'), sg.Text(size=(50,1), key='-CSI2-')],
              [sg.Text('Result IN EURO:'), sg.Text(size=(50,1), key='-CSI3-')],
              [sg.Text('Result In YUAN:'), sg.Text(size=(50,1), key='-CSI4-')],
              [sg.Text('Result In JPY:'), sg.Text(size=(50,1), key='-CSI5-')],
              [sg.Text('Result In SR:'), sg.Text(size=(50,1), key='-CSI6-')],
              [sg.Button('back')],
              [sg.Text(size=(50,1), key='-OUTPUT-1')]]
    window = sg.Window('Review Predect Type', layout)
    while True:
        event, values = window.read()
        if event == sg.WINDOW_CLOSED or event == 'Quit':
            break
        if event in (sg.WIN_CLOSED,):
            break
        if event == 'back':
            main()
            break
        if event == 'Predect Image Using Camera':
            cap_money = cv2.VideoCapture(0)
            retval_money, frame_money = cap_money.read()
            img_money= (frame_money)
            img_money = tf.expand_dims(img_money,0)
            img_money=img_money/255
            img_money=tf.image.resize(img_money,size=(224, 224))
            Prob_money=model.predict(img_money)
            ind_money=tf.argmax(Prob_money[0],axis=-1).numpy()
            res_img=str(labels[ind_money])
            mydb = mysql.connector.connect(
                host = "localhost",
                user = "root",
                password = "",
                database = "money_discovery_db")
            mycursor = mydb.cursor()
            sql1 = "INSERT INTO `test_al`(`test_result`, `test_date`, `test_time`) VALUES ('" + res_img + "',NOW(),NOW())"
            mycursor.execute(sql1)
            mydb.commit()
            #messagebox.showinfo("Result", labels[ind_mony] ) 
            sql_Query = "select lastValue * (select banknoteNumber from banknote where banknote_lable like (select test_result from test_al where test_id=(SELECT MAX(test_id) FROM `test_al`))) from exchange_rate where banknoteType like (select banknoteType from banknote where banknote_lable like (select test_result from test_al where test_id=(SELECT MAX(test_id) FROM `test_al`))) ;"
            mycursor.execute(sql_Query)
            recordUSD = mycursor.fetchone()
            sql_Query1 = "select lastValue * (select banknoteNumber from banknote where banknote_lable like (select test_result from test_al where test_id=(SELECT MAX(test_id) FROM `test_al`))) / (SELECT `lastValue` FROM `exchange_rate` WHERE  `banknoteType` like 'EURO' ORDER BY  `currencyID` DESC LIMIT 1)  from exchange_rate where banknoteType like (select banknoteType from banknote where banknote_lable like (select test_result from test_al where test_id=(SELECT MAX(test_id) FROM `test_al`))) ;"
            mycursor.execute(sql_Query1)
            recordEURO = mycursor.fetchone()
            sql_Query2 = "select lastValue * (select banknoteNumber from banknote where banknote_lable like (select test_result from test_al where test_id=(SELECT MAX(test_id) FROM `test_al`))) / (SELECT `lastValue` FROM `exchange_rate` WHERE  `banknoteType` like 'YUAN' ORDER BY  `currencyID` DESC LIMIT 1) from exchange_rate where banknoteType like (select banknoteType from banknote where banknote_lable like (select test_result from test_al where test_id=(SELECT MAX(test_id) FROM `test_al`))) ;"
            mycursor.execute(sql_Query2)        
            recordYUAN = mycursor.fetchone()
            sql_Query3 = "select lastValue * (select banknoteNumber from banknote where banknote_lable like (select test_result from test_al where test_id=(SELECT MAX(test_id) FROM `test_al`))) / (SELECT `lastValue` FROM `exchange_rate` WHERE  `banknoteType` like 'JPY' ORDER BY  `currencyID` DESC LIMIT 1)  from exchange_rate where banknoteType like (select banknoteType from banknote where banknote_lable like (select test_result from test_al where test_id=(SELECT MAX(test_id) FROM `test_al`))) ;"       
            mycursor.execute(sql_Query3)
            recordJPY = mycursor.fetchone()
            sql_Query4 = "select lastValue * (select banknoteNumber from banknote where banknote_lable like (select test_result from test_al where test_id=(SELECT MAX(test_id) FROM `test_al`))) / (SELECT `lastValue` FROM `exchange_rate` WHERE  `banknoteType` like 'SR' ORDER BY  `currencyID` DESC LIMIT 1) from exchange_rate where banknoteType like (select banknoteType from banknote where banknote_lable like (select test_result from test_al where test_id=(SELECT MAX(test_id) FROM `test_al`))) ;"
            mycursor.execute(sql_Query4)
            recordSR = mycursor.fetchone()
            mydb.close()
            response1 = "AI system check result: " + res_img
            window['-CSI1-'].update(response1)
            response2 = "AI system check result: " + str(recordUSD)
            window['-CSI2-'].update(response2)
            response3 = "AI system check result: " + str(recordEURO)
            window['-CSI3-'].update(response3)
            response4 = "AI system check result: " + str(recordYUAN)
            window['-CSI4-'].update(response4)
            response5 = "AI system check result: " + str(recordJPY)
            window['-CSI5-'].update(response5)
            response6 = "AI system check result: " + str(recordSR)
            window['-CSI6-'].update(response6)
    window.close()

# %%
"""
def Insert_Money_Type():
    import PySimpleGUI as sg
    from tkinter.filedialog import askopenfile
    from tkinter import messagebox
    import mysql.connector
    mydb = mysql.connector.connect(
        host = "localhost",
        user = "root",
        password = "",
        database = "money_discovery_db")
    mycursor = mydb.cursor()
    sql = "INSERT INTO `banknote`(`banknoteType`, `banknoteNumber`, `banknoteCountry`, `banknote_lable`) VALUES (%s , %s , %s, %s)"
    sg.theme('Light Blue 2')
    layout = [[sg.Text("Money System",text_color='brown',font = "Verdana 22 bold", pad=(175, 0))],
              [sg.Text("Insert Money Type Page",text_color='brown',font = "Verdana 20 bold", pad=(125, 0))],
              [sg.Text("Money Type",size=(15,1)),sg.Input(size=(30,1),key='MType')],
              [sg.Text("Money Value",size=(15,1)),sg.Input(size=(30,1),key='MValue')],
              [sg.Text("Money Country",size=(15,1)),sg.Input(size=(30,1),key='MCountry')],
              [sg.Text("Coin Denomination",size=(15,1)),sg.Input(size=(30,1),key='CD')],
              [sg.Button('Insert',size=(15,1))],
              [sg.Text("",text_color='brown',font = "Verdana 20 bold")],
              [sg.Button('back')],
              [sg.Text(size=(50,1), key='-OUTPUT-1')]]
    window = sg.Window('Insert Money Type Page', layout)
    while True:
        event, values = window.read()
        if event == sg.WINDOW_CLOSED or event == 'Quit':
            break
        if event in (sg.WIN_CLOSED,): 
            break
        if event == 'back':
            main_admin()
            break
        if event == 'Insert':
            MType = values['MType']
            MValue = values['MValue']
            MCountry = values['MCountry']
            CD = values['CD']
            val = (MType,MValue,MCountry,CD)
            mycursor.execute(sql, val)
            mydb.commit()
            mydb.close()
            messagebox.showinfo("Result", "Successfully")
    window.close()
    """
# Out:
# '\ndef Insert_Money_Type():\n    import PySimpleGUI as sg\n    from tkinter.filedialog import askopenfile\n    from tkinter import messagebox\n    import mysql.connector\n    mydb = mysql.connector.connect(\n        host = "localhost",\n        user = "root",\n        password = "",\n        database = "money_discovery_db")\n    mycursor = mydb.cursor()\n    sql = "INSERT INTO `banknote`(`banknoteType`, `banknoteNumber`, `banknoteCountry`, `banknote_lable`) VALUES (%s , %s , %s, %s)"\n    sg.theme(\'Light Blue 2\')\n    layout = [[sg.Text("Money System",text_color=\'brown\',font = "Verdana 22 bold", pad=(175, 0))],\n              [sg.Text("Insert Money Type Page",text_color=\'brown\',font = "Verdana 20 bold", pad=(125, 0))],\n              [sg.Text("Money Type",size=(15,1)),sg.Input(size=(30,1),key=\'MType\')],\n              [sg.Text("Money Value",size=(15,1)),sg.Input(size=(30,1),key=\'MValue\')],\n              [sg.Text("Money Country",size=(15,1)),sg.Input(size=(30,1),key=\'MCoun
# ...

# %%
def Insert_An_Exchange_Rate():
    import PySimpleGUI as sg
    from tkinter.filedialog import askopenfile
    from tkinter import messagebox
    import mysql.connector
    mydb = mysql.connector.connect(
        host = "localhost",
        user = "root",
        password = "",
        database = "money_discovery_db"
    )
    mycursor = mydb.cursor()
    sql = "INSERT INTO `exchange_rate`(`banknoteType`, `lastValue`, `Date`) VALUES (%s , %s ,NOW())"
    sg.theme('Light Blue 2')
    layout = [[sg.Text("Money System",text_color='brown',font = "Verdana 22 bold", pad=(150, 0))],
              [sg.Text("Insert Exchange Rate Page",text_color='brown',font = "Verdana 20 bold", pad=(100, 0))],
              [sg.Text("Money Type",size=(10,1)),sg.Combo(['SR', 'JPY', 'USD', 'EURO', 'YUAN'], enable_events=True, key='comboMType',size=(10,1))],
              [sg.Text("Money Value",size=(10,1)),sg.Input(size=(20,1),key='MValue')],
              [sg.Button('Insert',size=(10,1))],
              [sg.Text("",text_color='brown',font = "Verdana 20 bold")],
              [sg.Button('back')],
              [sg.Text(size=(50,1), key='-OUTPUT-1')]]
    window = sg.Window('Insert Exchange Rate Page', layout)
    while True:
        event, values = window.read()
        if event == sg.WINDOW_CLOSED or event == 'Quit':
            break
        if event in (sg.WIN_CLOSED,):
            break
        if event == 'back':
            main_admin()
            break
        if event == 'Insert':
            comboMType = values['comboMType']
            MValue = values['MValue']
            val = (comboMType,MValue)
            mycursor.execute(sql, val)
            mydb.commit()
            mydb.close()
            messagebox.showinfo("Result", "Successfully")
    window.close()

# %%
############################################################

# %%
import mysql.connector
def Edit_Profile():
    import mysql.connector
    import PySimpleGUI as sg
    from tkinter import messagebox
    mydb = mysql.connector.connect(host='localhost', user = 'root', passwd = '', database = 'money_discovery_db')
    mycursor = mydb.cursor()
    ##############################################
    def mail_check(mailwd):
        SpecialSym =['g', 'y', 'h', 'm', 'a', 'i', 'l']
        SpecialSym1 =['@']
        val = True          
        if not any(char in SpecialSym for char in mailwd):
            print('mail should have special word')
            messagebox.showinfo("Result", "mail should have special word")
            val = False
        if not any(char in SpecialSym1 for char in mailwd):
            print('mail should have special symbols @')
            messagebox.showinfo("Result", "mail should have special symbols @")
            val = False
        if val:
            return val
    ##############################################
    def password_check(passwd):
        SpecialSym =['$', '@', '#', '%']
        val = True
        if len(passwd) < 6:
            print('length should be at least 6')
            messagebox.showinfo("Result", "length should be at least 6")
            val = False
        if len(passwd) > 20:
            print('length should be not be greater than 8')
            messagebox.showinfo("Result", "length should be not be greater than 8")
            val = False         
        if not any(char.isdigit() for char in passwd):
            print('Password should have at least one numeral')
            messagebox.showinfo("Result", "Password should have at least one numeral")
            val = False          
        if not any(char.isupper() for char in passwd):
            print('Password should have at least one uppercase letter')
            messagebox.showinfo("Result", "Password should have at least one uppercase letter")
            val = False            
        if not any(char.islower() for char in passwd):
            print('Password should have at least one lowercase letter')
            messagebox.showinfo("Result", "Password should have at least one lowercase letter")
            val = False          
        if not any(char in SpecialSym for char in passwd):
            print('Password should have at least one of the symbols $@#')
            messagebox.showinfo("Result", "Password should have at least one of the symbols $@#")
            val = False
        if val:
            return val
    ##############################################
    def refreshTable1():
        mydb = mysql.connector.connect(host='localhost', user = 'root', passwd = '', database = 'money_discovery_db')
        mycursor = mydb.cursor()
        val2 = []
        mycursor.execute("SELECT `adminID`, `adminName`, `adminEmail` FROM `admin`")
        for i in mycursor:
            val2.append(list(i))
        window['-table-'].Update(values=val2) 
        
    val1= []
    mycursor.execute("SELECT `adminID`, `adminName`, `adminEmail` FROM `admin`")
    for i in mycursor:
        val1.append(list(i))
    headers = ['ID', 'Name', 'Email']
    sg.theme("Light Blue 2")
    layout1 = [[sg.T("Here Are The Money Type:")],[sg.Table(headings=headers, values = val1,display_row_numbers=True,enable_events=True,justification='center',key='-table-')]]
    layout2 =[[sg.T('Admin Name:', size=(15,1)), sg.Input("",key='nameA', size=(15,1))],
              [sg.T('Admin Email:', size=(15,1)), sg.Input("",key='mailA', size=(15,1))],
              [sg.T('Last Password:', size=(15,1)), sg.Input("",key='Lpass', size=(15,1))],
              [sg.T('New Password:', size=(15,1)), sg.Input("",key='Npass', size=(15,1))],
              [sg.Button('Add New', key='-add-', size=(15,1))],
              [sg.Button('Up Date', key='-UpD-', size=(15,1))],
              [sg.Button('Delete', key='-del-', size=(15,1))]]
    mainLayout = [[sg.Column(layout1), sg.Column(layout2)],
                  [sg.Button('back'),  sg.Button('Refresh', key='-ref-', size=(10,1))]]
    window = sg.Window('Admin Profile',  mainLayout)
    table = window['-table-']
    while True:
        event, values = window.read()
        print(event, values)
        if event == sg.WIN_CLOSED:
            break
        if event == 'back':
            main_admin() 
            break
        if event == '-add-':
            sql = "INSERT INTO `admin`(`adminName`, `adminEmail`, `adminPassword`) VALUES (%s ,%s ,%s)"
            nameAA = values['nameA']
            mailAA = values['mailA']
            NpassA = values['Npass']
            NpassAA = NpassA
            mailAAA = mailAA
            if (password_check(NpassA)):
                print("Password is valid")
                messagebox.showinfo("Result", "Password is valid")
                if (mail_check(mailAA)):
                    print("Email is valid")
                    messagebox.showinfo("Result", "Email is valid")
                    val = (nameAA,mailAA,NpassA)
                    mycursor.execute(sql,val)
                    mydb.commit()
                    #mydb.close()
                    print("Successfully Insert New Admin")
                    messagebox.showinfo("Result", "Successfully Insert New Admin")
                    refreshTable1()
                else:                   
                    print("Mail is invalid")
                    messagebox.showinfo("Result", "Mail is invalid")
            else:
                print("Password is invalid")
                messagebox.showinfo("Result", "Password is invalid")
        if event == '-UpD-':
            nameAA = values['nameA']
            mailAA = values['mailA']            
            NpassA = values['Npass']
            LpassA = values['Lpass']
            NpassAA = NpassA
            mailAAA = mailAA
            if (password_check(NpassA)):
                print("Password is valid")
                messagebox.showinfo("Result", "Password is valid")
                if (mail_check(mailAA)):
                    print("Email is valid")
                    messagebox.showinfo("Result", "Email is valid")
                    indexes = values['-table-']
                    print(indexes)
                    id_list = []
                    if indexes:
                        for index in indexes:
                            selected_list = val1[index]#the row select in table
                            print(selected_list[2])
                            id_list.append(selected_list[0])#id of record in table in database
                            print(id_list)
                            #messagebox.showinfo("Result", id_list)
                            for index in sorted(indexes, reverse=True):
                                query = "UPDATE `admin` SET `adminName`='"+nameAA+"',`adminEmail`='"+mailAA+"',`adminPassword`='"+NpassA+"' WHERE `adminPassword` like '"+LpassA+"' and `adminID` IN (%s) " % ",".join(["%s"] * len(id_list))
                                mycursor.execute(query, id_list)
                                mydb.commit()
                                print("Successfully Up Date")
                                messagebox.showinfo("Result", "Successfully Up Date")
                                refreshTable1()
        if event == '-ref-':
            refreshTable1()
            messagebox.showinfo("Result", "Successfully Refresh")
        if event == '-del-':
            indexes = values['-table-']
            print(indexes)
            id_list = []
            if indexes:
                for index in indexes:
                    selected_list = val1[index]#the row select in table
                    print(selected_list[2])
                    id_list.append(selected_list[0])#id of record in table in database
                    #print(id_list)
                    #messagebox.showinfo("Result", id_list)
                    for index in sorted(indexes, reverse=True):
                        query = "DELETE FROM admin WHERE adminID IN (%s)" % ",".join(["%s"] * len(id_list))
                        mycursor.execute(query, id_list)
                        mydb.commit()
                        print("Successfully Delete")
                        messagebox.showinfo("Result", "Successfully Delete")
                        refreshTable1()
                    refreshTable1()
                refreshTable1()
    window.close()

# %%
import mysql.connector
def Edit_Money():
    import mysql.connector
    import PySimpleGUI as sg
    from tkinter import messagebox
    mydb = mysql.connector.connect(host='localhost', user = 'root', passwd = '', database = 'money_discovery_db')
    mycursor = mydb.cursor()
    def refreshTable():
        mydb = mysql.connector.connect(host='localhost', user = 'root', passwd = '', database = 'money_discovery_db')
        mycursor = mydb.cursor()
        val2 = []
        mycursor.execute("SELECT * FROM `banknote`")
        for i in mycursor:
            val2.append(list(i))
            #print(val2)
        window['-table-'].Update(values=val2)
        
    val1= []
    mycursor.execute("SELECT * FROM `banknote`")
    for i in mycursor:
        val1.append(list(i))
        #print(val1)
        #window['-table-'].Update(values=val1)
    headers = ['ID', 'Type', 'Value', 'Country', 'Label']
    sg.theme("Light Blue 2")
    layout1 = [[sg.T("Here Are The Money Type:")],[sg.Table(headings=headers, values = val1,display_row_numbers=True,enable_events=True,justification='center',key='-table-')]]
    layout2 =[[sg.T('Money Type:', size=(15,1)), sg.Input("",key='MType', size=(15,1))],
              [sg.T('Money Value:', size=(15,1)), sg.Input("",key='MValue', size=(15,1))],
              [sg.T('Money Country:', size=(15,1)), sg.Input("",key='MCountry', size=(15,1))],
              [sg.T('Coin Denomination:', size=(15,1)), sg.Input("",key='CD', size=(15,1))],
              [sg.Button('Add New', key='-add-', size=(15,1))]]
    mainLayout = [[sg.Column(layout1), sg.Column(layout2)],
                  [ sg.Button('back'), sg.Button('Up Date', key='-UpD-', size=(10,1)), sg.Button('Delete', key= '-del-', size=(10,1)),sg.Button('Refresh', key='-ref-', size=(10,1))]]
    window = sg.Window('AI Money Type',  mainLayout)
    table = window['-table-']
    while True:
        event, values = window.read()
        print(event, values)
        if event == sg.WIN_CLOSED:
            break
        if event == 'back':
            main_admin() 
            break
        if event == '-add-':
            sql = "INSERT INTO `banknote`(`banknoteType`, `banknoteNumber`, `banknoteCountry`, `banknote_lable`) VALUES (%s , %s , %s, %s)"
            MType = values['MType']
            MValue = values['MValue']
            MCountry = values['MCountry']
            CD = values['CD']
            val = (MType,MValue,MCountry,CD)
            mycursor.execute(sql, val)
            mydb.commit()
            #mydb.close()
            print("Successfully Insert")
            messagebox.showinfo("Result", "Successfully Insert")
            refreshTable()
        if event == '-del-':
            indexes = values['-table-']
            print(indexes)
            id_list = []
            if indexes:
                for index in indexes:
                    selected_list = val1[index]#the row select in table
                    print(selected_list[2])
                    id_list.append(selected_list[0])#id of record in table in database
                    #print(id_list)
                    #messagebox.showinfo("Result", id_list)
                    for index in sorted(indexes, reverse=True):
                        query = "DELETE FROM banknote WHERE banknoteID IN (%s)" % ",".join(["%s"] * len(id_list))
                        mycursor.execute(query, id_list)
                        mydb.commit()
                        print("Successfully Delete")
                        messagebox.showinfo("Result", "Successfully Delete")
                        refreshTable()
        if event == '-UpD-':
            MType = values['MType']
            MValue = values['MValue']
            MCountry = values['MCountry']
            CD = values['CD']
            indexes = values['-table-']
            print(indexes)
            id_list = []
            if indexes:
                for index in indexes:
                    selected_list = val1[index]#the row select in table
                    print(selected_list[2])
                    id_list.append(selected_list[0])#id of record in table in database
                    #print(id_list)
                    #messagebox.showinfo("Result", id_list)
                    for index in sorted(indexes, reverse=True):
                        query = "UPDATE `banknote` SET `banknoteType`='"+MType+"',`banknoteNumber`="+MValue+",`banknoteCountry`='"+MCountry+"',`banknote_lable`='"+CD+"' WHERE banknoteID IN (%s)" % ",".join(["%s"] * len(id_list))
                        mycursor.execute(query, id_list)
                        mydb.commit()
                        print("Successfully Up Date")
                        messagebox.showinfo("Result", "Successfully Up Date")
                        refreshTable()
                        
                        
        if event == '-ref-':
            refreshTable()
            messagebox.showinfo("Result", "Successfully Refresh")
    window.close()

# %%
#####################################################

# %%
def main():
    import PySimpleGUI as sg
    from tkinter.filedialog import askopenfile
    sg.theme('Light Blue 2')
    layout = [[sg.Button('Manager'),sg.Text("Money System Main Page",text_color='brown',font = "Verdana 20 bold")],
              [sg.Button('Enter System')],
              [sg.Text(size=(50,1), key='-OUTPUT-1')]]
    window = sg.Window('Home Page', layout, element_justification='c')
    while True:
        event, values = window.read()
        if event == sg.WINDOW_CLOSED or event == 'Quit':
            break
        if event in (sg.WIN_CLOSED,):
            break
        if event == 'Manager':
            Login_Admin()
            break
        if event == 'Enter System':
            Main_User()
            break
    window.close()

# %%
main()
# Out:
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# Input In [17], in <cell line: 1>()
# ----> 1 main()
#
# Input In [16], in main()
#      17         break
#      18     if event == 'Enter System':
# ---> 19         Main_User()
#      20         break
#      21 window.close()
#
# Input In [3], in Main_User()
#      22 rt = values['Mcombo']
#      23 if rt == "Use Of Camera":
# ---> 24     Umoney_Cap()
#      25     break
#      26 if rt == "Import Photo":
#
# Input In [9], in Umoney_Cap()
#      60 recordUSD = mycursor.fetchone()
# ...
